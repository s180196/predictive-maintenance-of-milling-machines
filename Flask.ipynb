# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Mini1
# Out:
# /content/drive/MyDrive/Mini1

# %%
# !pip install pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-6.0.0-py3-none-any.whl size=19867 sha256=cfb0420232bdcd3a9d363db09e414dcf43f6e39f44e0c9a44625b464a41fc1cc
#   Stored in directory: /root/.cache/pip/wheels/5c/42/78/0c3d438d7f5730451a25f7ac6cbf4391759d22a67576ed7c2c
# Successfully built pyngrok
# ...

# %%
pip install ngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.6 MB/s eta 0:00:00
# ...

# %%
# !pip install flask
# !pip install flask-ngrok

# %%
from flask import Flask
from pyngrok import ngrok

# %%
port_no=5000

# %%
import numpy as np
from flask import Flask, request, render_template
import pickle

# %%
app=Flask(__name__)
model=pickle.load(open('/content/drive/MyDrive/Mini1/model10.pkl','rb'))
ngrok.set_auth_token("2Sd0N1qsap6AoeOHNFjiazzE394_5LuCn2om2JepT6k3zQq6c")
public_url=ngrok.connect(port_no).public_url
print(public_url)

@app.route('/')
def man():
  return render_template('index2.html')

@app.route('/home',methods=['POST'])
def home():
  at=float(request.form["input1"])
  pt=float(request.form["input2"])
  rt=float(request.form["input3"])
  t=float(request.form["input4"])
  tw=float(request.form["input5"])
  arr=np.array([[at,pt,rt,t,tw]])
  pred=model.predict(arr)
  str=""
  if pred<1:
    fn="Machine is  : Not Failed"
    res="Good Condition"
  elif pred==1:
    fn="Machine is  :Failed"
    res="Reason For Failure : Tool wear Failure"
  elif pred==2:
    fn="Machine is  :Failed"
    res="Reason For Failure : Heat Dissipation Failure"
  elif pred==3:
    fn="Machine is  :Failed"
    res="Reason For Failure : Power Failure"
  elif pred==4:
    fn="Machine is  :Failed"
    res="Reason For Failure : Oberstrian Failure"
  elif pred==5:
    fn="Machine is  :Failed"
    res="Reason For Failure : Random Failure"

  return render_template('index2.html', prediction_text=fn,reason=res)

if __name__=="__main__":
  app.run(port=port_no)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-07-24T15:52:15+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# https://b58d-35-230-68-126.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [24/Jul/2023 15:52:28] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [24/Jul/2023 15:52:29] "GET /image.jpg HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [24/Jul/2023 15:52:29] "GET /image1.jfif HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [24/Jul/2023 15:52:29] "GET /favicon.ico HTTP/1.1" 404 -
# ...

# %%
""
